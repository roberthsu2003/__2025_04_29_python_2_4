# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()
client = genai.Client()
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="天空為什麼是藍的"
)
print(response.text)
# Out:
# 天空之所以是藍色的，主要歸因於一種稱為**瑞利散射 (Rayleigh Scattering)** 的物理現象。
#
# 要理解這個現象，我們需要了解以下幾點：
#
# 1.  **陽光的組成：** 陽光看似白色，但其實是由各種顏色的光組成的，就像彩虹一樣（紅、橙、黃、綠、藍、靛、紫）。不同顏色的光有不同的波長，其中紅光的波長最長，藍光和紫光的波長最短。
#
# 2.  **地球的大氣層：** 地球的大氣層主要由氮氣 (N₂) 和氧氣 (O₂) 分子組成，這些分子非常微小。
#
# 3.  **瑞利散射的原理：** 當陽光穿過大氣層時，這些微小的氣體分子會將光線向四面八方散射開來。瑞利散射的特性是，**光線的波長越短，被散射的程度就越厲害**。
#
#     *   **為什麼天空是藍的？** 由於藍光和紫光的波長比紅光、黃光等其他顏色光的波長短得多，因此它們被大氣分子散射的效率最高，強度最大。當陽光照射到地球大氣層時，大部分的藍光和紫光會被大氣分子散射到四面八方，其中一部分被散射到我們的眼睛裡，所以我們仰望天空時，看到的就是藍色的。
#
#     *   **為什麼不是紫色？** 雖然紫光被散射的效率比藍光更高，但有兩個原因導致我們看到的是藍色而不是紫色：
#         *   **太陽光本身：** 太陽光本身在藍色波段的強度比紫色波段略強。
#         *   **人眼敏感度：** 人眼對藍光的敏感度比對紫光更高。這兩種因素綜合作用下，使得我們感知到的天空顏色是藍色。
#
# ---
#
# **相關現象的解釋：**
#
# *   **日出日落時天空為什麼是紅色或橙色？**
#     在日出和日落時，太陽光需要穿過更厚、更長的大氣層才能到達我們的眼睛。由於藍光被散射得非常厲害，在陽光穿過這麼長的大氣路徑後，大部分的藍光和紫光都已經被散射開了。剩下的、沒有被大量散射的光線主要是波長較長的紅光、橙光和黃光，所以此時我們看到的天空或太陽呈現出紅色或橙色。
#
# *   **雲朵為什麼是白色或灰色？**
#     雲朵由水滴或冰晶組成，它們的顆粒比大氣分子大得多。當陽光照射到這些較大的顆粒時，散射的方式就不同了，它對所有顏色的光幾乎是均勻散射的（這稱為米氏散射）。因此，當所有顏色的光被均勻散射後混合在一起，我們看到的雲朵就是白色的。如果雲層太厚，光線無法穿透，或上層雲朵遮擋了光線，底部就會顯得灰色。
#
# *   **在外太空看天空為什麼是黑色的？**
#     因為外太空沒有大氣層來散射陽光。陽光是直射的，沒有散射光，所以背景自然是漆黑一片，星星也清晰可見。
