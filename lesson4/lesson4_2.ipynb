# %%
value:int = int(input("請輸入一個數值:"))
if value >= 120:
    if value <= 220:
        print("數值在120~220")
# Out:
# 數值在120~220

# %%
value:int = int(input("請輸入一個數值:"))
if value < 120:
    print("小於120")
    
if value > 220:
    print("大於220")
# Out:
# 大於220

# %%
value:int = int(input("請輸入一個數值:"))
if value >= 120 and value <= 220: #使用邏輯運算子
    print("數值在120~220")
# Out:
# 數值在120~220

# %%
value:int = int(input("請輸入一個數值:"))
if value < 120 or value > 220:
    print("小於120或者大於220")
# Out:
# 小於120或都大於220
