# %% [markdown]
# scores = pd.DataFrame(np.random.randint(50, 101, size=(50, 5)), columns=list('ABCDE'))

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series

# %%
score_pd
# Out:
# 科目    國文  英文   數學   地理   歷史   總分    平均
# 學號
# 學生1   65  61   54   81  100  361  72.2
# 學生2   60  92   57   84   88  381  76.2
# 學生3   88  74   64  100   66  392  78.4
# 學生4   96  60   87   81   77  401  80.2
# 學生5   82  92   69   63   81  387  77.4
# 學生6   82  73   80   97   92  424  84.8
# 學生7   88  61   91   73   62  375  75.0
# 學生8   55  88   79   75   70  367  73.4
# 學生9   94  85   88   92   81  440  88.0
# 學生10  52  89   51   71   59  322  64.4
# 學生11  58  83   90   50   70  351  70.2
# 學生12  78  86   56   80   94  394  78.8
# 學生13  87  52   72   91   53  355  71.0
# 學生14  81  86   50   68   53  338  67.6
# 學生15  54  98   70   66   51  339  67.8
# 學生16  73  60   78   67   79  357  71.4
# 學生17  52  54   55   65   80  306  61.2
# 學生18  95  54   68   65   62  344  68.8
# 學生19  85  93  100   68  100  446  89.2
# 學生20  95  84   53   54   67  353  70.6
# 學生21  74  52   54   73   83  336  67.2
# 學生22  94  76   52   66   51  339  67.8
# 學生23  95  94   81   88   60  418  83.6
# 學生24  76  59   57   93   84  369  73.8
# 學生25  52  65   82   64   57  320  64.0
# 學生26  58  75   54   55   98  340  68.0
# 學生27  93  51   67   66   66  343  68.6
# 學生28  84  62   71  100   90  407  81.4
# 學生29  63  68  100   56   62  349  69.8
# 學生30  53  52   57   84   85  331  66.2
# 學生31  98  85   93   78   63  417  83.4
# 學生32  65  82   92   96   94  429  85.8
# 學生33  58  63   75   95   70  361  72.2
# 學生34  92  92   94   92   54  424  84.8
# 學生35  73  73   68   69   94  377  75.4
# 學生36  97  55   61   60   85  358  71.6
# 學生37  65  82   82   96   74  399  79.8
# 學生38  96  84   76   59   84  399  79.8
# 學生39  62  93   90   88   74  407  81.4
# 學生40  81  97   90   73   70  411  82.2
# 學生41  73  65   94   97   96  425  85.0
# 學生42  78  54   77   53   61  323  64.6
# 學生43  99  59   82   58   84  382  76.4
# 學生44  76  54   91   57   66  344  68.8
# 學生45  68  80   76   87   79  390  78.0
# 學生46  63  58   70   71   55  317  63.4
# 學生47  90  87   73   54   72  376  75.2
# 學生48  96  75   70   82   77  400  80.0
# 學生49  89  88   83   68   78  406  81.2
# 學生50  92  80   72   54   71  369  73.8
