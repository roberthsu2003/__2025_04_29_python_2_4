# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.469318  0.150324
# 1    a  two  1.136034  0.740291
# 2    b  one  1.287498  0.222871
# 3    b  two  1.030870 -0.418378
# 4    a  one -0.427848  1.382220

# %%
df.groupby(by="key1")[['data1','data2']].sum()
# Out:
# key1          a         b
# data1  0.238868  2.318368
# data2  2.272834 -0.195507

# %%
df1 = df.groupby(by=['key1','key2']).sum()
df1.columns.name = "data"
df1
# Out:
# data          data1     data2
# key1 key2
# a    one  -0.897166  1.532544
#      two   1.136034  0.740291
# b    one   1.287498  0.222871
#      two   1.030870 -0.418378

# %%
df1.stack().unstack(level=['key2','data'])
# Out:
# key2       one                 two
# data     data1     data2     data1     data2
# key1
# a    -0.897166  1.532544  1.136034  0.740291
# b     1.287498  0.222871  1.030870 -0.418378
