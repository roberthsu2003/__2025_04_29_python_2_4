# %% [markdown]
# https://www.perplexity.ai/search/67a9fadb-8589-4e27-8d52-e48555a9b45d

# %%
import numpy as np
import pandas as pd

data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}

pd.DataFrame(data,index=["第1","第2","第3","第4"])
# Out:
#     apples  oranges
# 第1       3        0
# 第2       2        3
# 第3       0        7
# 第4       1        2

# %%
data = np.random.randint(50, 101,size=(5,5))
df = pd.DataFrame(data,
            index=["學生1","學生2","學生3","學生4","學生5"],
            columns=["國文","英文","數學","地理","歷史"])
df
# Out:
#      國文  英文  數學  地理  歷史
# 學生1  77  80  64  82  66
# 學生2  82  94  70  97  77
# 學生3  88  95  75  93  64
# 學生4  97  80  60  63  54
# 學生5  78  57  59  57  91

# %%
#依據欄位名稱的選取
df['國文']
df[['國文','英文']]
# Out:
#      國文  英文
# 學生1  74  95
# 學生2  53  79
# 學生3  85  90
# 學生4  99  79
# 學生5  98  67

# %%
#可以使用numpy的統計function
sum = np.sum(df,axis=1)
mean = np.mean(df,axis=1)
df['總分'] = sum
df['平均'] = mean

# %%
df
# Out:
#      國文  英文  數學  地理  歷史   總分    平均
# 學生1  77  80  64  82  66  369  73.8
# 學生2  82  94  70  97  77  420  84.0
# 學生3  88  95  75  93  64  415  83.0
# 學生4  97  80  60  63  54  354  70.8
# 學生5  78  57  59  57  91  342  68.4

# %%
#依據列的選取
#.loc[] -> 依據名稱
#.iloc[] ->這是依據索引

df.loc['學生1']
df.loc[['學生1','學生2']]
df.iloc[0] #類似numpy的選取
df.iloc[:2] 
df.iloc[0,:5]
df.iloc[:2,:5]
# Out:
#      國文  英文  數學  地理  歷史
# 學生1  77  80  64  82  66
# 學生2  82  94  70  97  77
